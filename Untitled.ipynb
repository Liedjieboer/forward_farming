# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/Users/nico_marais/Downloads/USC00046074.csv")

# %%
df.tail()
# Out:
#           STATION     DATE  LATITUDE  LONGITUDE  ELEVATION  \
# 1477  USC00046074  2022-06   38.2777  -122.2647       10.7
# 1478  USC00046074  2022-07   38.2777  -122.2647       10.7
# 1479  USC00046074  2022-08   38.2777  -122.2647       10.7
# 1480  USC00046074  2022-09   38.2777  -122.2647       10.7
# 1481  USC00046074  2022-10   38.2777  -122.2647       10.7
#
#                             NAME   CDSD CDSD_ATTRIBUTES   CLDD  \
# 1477  NAPA STATE HOSPITAL, CA US  127.8             NaN   86.6
# 1478  NAPA STATE HOSPITAL, CA US  183.3             NaN   55.5
# 1479  NAPA STATE HOSPITAL, CA US  279.1             NaN   95.8
# 1480  NAPA STATE HOSPITAL, CA US  385.9             NaN  106.8
# 1481  NAPA STATE HOSPITAL, CA US  399.7             NaN   13.8
#
#      CLDD_ATTRIBUTES  ...  PRCP PRCP_ATTRIBUTES  SNOW SNOW_ATTRIBUTES   TAVG  \
# 1477             4,7  ...   0.0            ,,,7   NaN             NaN  21.47
# 1478             3,7  ...   0.0           3,,,7   NaN             NaN  20.24
# 1479             3,7  ...   6.9           3,,,7   NaN             NaN  21.76
# 1480             2,7  ...  22.1            ,,,7   NaN             NaN  22.05
# 1481             3,7  ...   0.0            ,,,7   NaN             NaN  17.19
#
#      TAVG_ATTRIBUTES   TMAX TMAX_ATTRIBUTES   TMIN TMIN_ATTRIBUTES
# 1477             4,7  29.82           4,,,7  13.12           4,,,7
# 1478             3,7  27.18           3,,,7  13.29           3,,,7
# 1479             3,7  29.59           3,,,7  13.93           3,,,7
# 1480             2,7  30.95           2,,,7  13.15           2,,,7
# 1481             3,7  24.86           3,,,7   9.52           3,,,7
#
# [5 rows x 58 columns]

# %%
df_napa = df[["NAME","DATE","TAVG","TMAX","TMIN"]]

# %%
df_napa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1482 entries, 0 to 1481
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NAME    1482 non-null   object
#  1   DATE    1482 non-null   object
#  2   TAVG    1454 non-null   float64
#  3   TMAX    1454 non-null   float64
#  4   TMIN    1462 non-null   float64
# dtypes: float64(3), object(2)
# memory usage: 58.0+ KB

# %%
df_napa["DATE"] = pd.to_datetime(df_napa["DATE"])
# Out:
# /var/folders/sq/vmyxb1t15h30lrlq40w06g2r0000gn/T/ipykernel_13565/3016701734.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_napa["DATE"] = pd.to_datetime(df_napa["DATE"])

# %%
df_napa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1482 entries, 0 to 1481
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NAME    1482 non-null   object
#  1   DATE    1482 non-null   datetime64[ns]
#  2   TAVG    1454 non-null   float64
#  3   TMAX    1454 non-null   float64
#  4   TMIN    1462 non-null   float64
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 58.0+ KB

# %%
df_filtered = df_napa[df_napa["DATE"] >= "1978-01-01"]

# %%
df_filtered
# Out:
#                             NAME       DATE   TAVG   TMAX   TMIN
# 946   NAPA STATE HOSPITAL, CA US 1978-01-01  10.88  14.98   6.77
# 947   NAPA STATE HOSPITAL, CA US 1978-02-01  11.96  17.36   6.55
# 948   NAPA STATE HOSPITAL, CA US 1978-03-01  14.71  20.29   9.13
# 949   NAPA STATE HOSPITAL, CA US 1978-04-01  13.20  19.81   6.60
# 950   NAPA STATE HOSPITAL, CA US 1978-05-01  18.33  27.15   9.51
# ...                          ...        ...    ...    ...    ...
# 1477  NAPA STATE HOSPITAL, CA US 2022-06-01  21.47  29.82  13.12
# 1478  NAPA STATE HOSPITAL, CA US 2022-07-01  20.24  27.18  13.29
# 1479  NAPA STATE HOSPITAL, CA US 2022-08-01  21.76  29.59  13.93
# 1480  NAPA STATE HOSPITAL, CA US 2022-09-01  22.05  30.95  13.15
# 1481  NAPA STATE HOSPITAL, CA US 2022-10-01  17.19  24.86   9.52
#
# [536 rows x 5 columns]

# %%
df_filtered["day"] = df_filtered["DATE"].map(lambda x: x.day)
df_filtered["month"] = df_filtered["DATE"].map(lambda x: x.month)
df_filtered["year"] = df_filtered["DATE"].map(lambda x: x.year)
# Out:
# /var/folders/sq/vmyxb1t15h30lrlq40w06g2r0000gn/T/ipykernel_13565/4287400589.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered["day"] = df_filtered["DATE"].map(lambda x: x.day)
# /var/folders/sq/vmyxb1t15h30lrlq40w06g2r0000gn/T/ipykernel_13565/4287400589.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered["month"] = df_filtered["DATE"].map(lambda x: x.month)
# /var/folders/sq/vmyxb1t15h30lrlq40w06g2r0000gn/T/ipykernel_13565/4287400589.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered["year"] = df_filtered["DATE"].map(lambda x: x.year)

# %%
df_filtered.drop(columns="DATE")
# Out:
#                             NAME   TAVG   TMAX   TMIN  day  month  year
# 946   NAPA STATE HOSPITAL, CA US  10.88  14.98   6.77    1      1  1978
# 947   NAPA STATE HOSPITAL, CA US  11.96  17.36   6.55    1      2  1978
# 948   NAPA STATE HOSPITAL, CA US  14.71  20.29   9.13    1      3  1978
# 949   NAPA STATE HOSPITAL, CA US  13.20  19.81   6.60    1      4  1978
# 950   NAPA STATE HOSPITAL, CA US  18.33  27.15   9.51    1      5  1978
# ...                          ...    ...    ...    ...  ...    ...   ...
# 1477  NAPA STATE HOSPITAL, CA US  21.47  29.82  13.12    1      6  2022
# 1478  NAPA STATE HOSPITAL, CA US  20.24  27.18  13.29    1      7  2022
# 1479  NAPA STATE HOSPITAL, CA US  21.76  29.59  13.93    1      8  2022
# 1480  NAPA STATE HOSPITAL, CA US  22.05  30.95  13.15    1      9  2022
# 1481  NAPA STATE HOSPITAL, CA US  17.19  24.86   9.52    1     10  2022
#
# [536 rows x 7 columns]

# %%
df_df = df_filtered.groupby("year").mean().drop(columns=["day","month"])
df_df
# Out:
# /var/folders/sq/vmyxb1t15h30lrlq40w06g2r0000gn/T/ipykernel_13565/1044810839.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_df = df_filtered.groupby("year").mean().drop(columns=["day","month"])
#            TAVG       TMAX      TMIN
# year
# 1978  15.360000  22.644167  8.075833
# 1979  15.222727  22.422727  8.025455
# 1980  15.003333  22.220833  7.781667
# 1981  15.895000  22.884167  8.904167
# 1982  14.545000  21.104167  7.990833
# 1983  16.371818  22.745455  9.458333
# 1984  15.643333  22.765000  8.521667
# 1985  14.720000  21.533333  7.905000
# 1986  16.114000  22.634000  9.592000
# 1987  15.100833  21.709167  8.492500
# 1988  15.328333  22.240833  8.416667
# 1989  14.623333  21.505000  7.739167
# 1990  14.944545  21.864545  8.025455
# 1991  14.777500  21.676667  7.875833
# 1992  15.494167  22.210000  8.777500
# 1993  15.106667  21.626667  8.585000
# 1994  14.625000  21.399167  7.850833
# 1995  15.972500  22.378333  9.569167
# 1996  16.551000  23.667000  9.436000
# 1997  16.163333  23.130833  9.192500
# 1998  14.985833  21.264167  8.705000
# 1999  14.803333  21.701667  7.905000
# 2000  15.444167  22.125000  8.760833
# 2001  15.715833  22.680833  8.748333
# 2002  15.430000  22.608333  8.250833
# 2003  15.846667  22.762500  8.927500
# 2004  15.962500  22.726667  9.201667
# 2005  15.580833  22.202500  8.959167
# 2006  15.400000  22.120000  8.679167
# 2007  15.533333  22.777500  8.290833
# 2008  15.521667  22.864167  8.179167
# 2009  15.436667  22.605000  8.266667
# 2010  15.098333  21.574167  8.621667
# 2011  14.851667  21.559167  8.145000
# 2012  15.521667  22.747500  8.296667
# 2013  15.613333  23.495833  7.731667
# 2014  16.919167  24.010000  9.830000
# 2015  16.492500  23.840833  9.144167
# 2016  16.036667  22.799167  9.275833
# 2017  16.325000  23.211000  9.442000
# 2018  15.739167  22.998333  8.476667
# 2019  15.996667  23.035000  8.955833
# 2020  16.621667  24.310000  8.934167
# 2021  15.590833  22.593333  8.584167
# 2022  17.119000  24.982000  9.255000

# %%
napa_score = ['9','9','7','8','9','9','8','8','7','8','9','9','10','7','8','8','8','8','9','7','8','7','10','6','8','8','6','8','9','9','7','5','8','7','10','4','4','6','5','6','6']
napa_score.reverse()

# %%
df_df = df_df.head(41)
df_df["score"] = np.array(napa_score)

df_df["score"] = pd.to_numeric(df_df["score"])
# Out:
# /var/folders/sq/vmyxb1t15h30lrlq40w06g2r0000gn/T/ipykernel_13565/1651286819.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_df["score"] = np.array(napa_score)
# /var/folders/sq/vmyxb1t15h30lrlq40w06g2r0000gn/T/ipykernel_13565/1651286819.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_df["score"] = pd.to_numeric(df_df["score"])

# %%
df_df.head()
# Out:
#            TAVG       TMAX      TMIN  score
# year
# 1978  15.360000  22.644167  8.075833      6
# 1979  15.222727  22.422727  8.025455      6
# 1980  15.003333  22.220833  7.781667      5
# 1981  15.895000  22.884167  8.904167      6
# 1982  14.545000  21.104167  7.990833      4

# %%
sns.regplot(x=df_df["TMIN"], y=df_df["score"])
# Out:
# <AxesSubplot: xlabel='TMIN', ylabel='score'>

# %%
sns.regplot(x=df_df["TMAX"], y=df_df["score"], color="orange")
# Out:
# <AxesSubplot: xlabel='TMAX', ylabel='score'>

# %%
sns.regplot(x=df_df["TAVG"], y=df_df["score"], color="green")
# Out:
# <AxesSubplot: xlabel='TAVG', ylabel='score'>

# %%
bordeaux_score = ['7',
  '9',
  '8',
  '9',
  '7',
  '10',
  '9',
  '8',
  '5',
  '8',
  '5',
  '10',
  '10',
  '7',
  '6',
  '7',
  '10',
  '7',
  '8',
  '6',
  '8',
  '10',
  '7',
  '8',
  '5',
  '9',
  '8',
  '5',
  '5',
  '3',
  '5',
  '10',
  '9',
  '8',
  '5',
  '8',
  '8',
  '5',
  '7',
  '10',
  '6',
  '4',
  '7',
  '7']

# %%
dijon_score = ['9',
  '9',
  '8',
  '8',
  '9',
  '9',
  '8',
  '7',
  '9',
  '7',
  '9',
  '9',
  '7',
  '6',
  '7',
  '10',
  '5',
  '8',
  '9',
  '7',
  '7',
  '9',
  '8',
  '7',
  '9',
  '8',
  '4',
  '9',
  '6',
  '8',
  '10',
  '9',
  '8',
  '6',
  '6',
  '9',
  '4',
  '7',
  '5',
  '6',
  '7',
  '6',
  '9']
