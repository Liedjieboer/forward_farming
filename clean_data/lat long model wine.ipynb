# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from nltk.tokenize import word_tokenize

# %%
data = pd.read_csv('clean_winemag_coord.csv')
data
# Out:
#        Unnamed: 0 country                                        description  \
# 0               4      US  Much like the regular bottling from 2012, this...
# 1              21      US  A sleek mix of tart berry, stem and herb, alon...
# 2              25      US  Oak and earth intermingle around robust aromas...
# 3              35      US  As with many of the Erath 2010 vineyard design...
# 4              41      US  A stiff, tannic wine, this slowly opens and br...
# ...           ...     ...                                                ...
# 17296      129936  France  A blend from several premier cru vineyards in ...
# 17297      129940      US  This is the winery's bells and whistles Chardo...
# 17298      129941      US  A Chardonnay with an unusual companion, 8% Sém...
# 17299      129949      US  There's no bones about the use of oak in this ...
# 17300      129967      US  Citation is given as much as a decade of bottl...
#
#                 region_1        lat         lon
# 0      Willamette Valley  44.942554 -122.933762
# 1                 Oregon  43.804133 -120.554201
# 2           Sonoma Coast  38.424211 -123.101173
# 3            McMinnville  45.210751 -123.194487
# 4      Willamette Valley  44.942554 -122.933762
# ...                  ...        ...         ...
# 17296            Pommard  47.009310    4.795325
# 17297          Mendocino  39.307674 -123.799459
# 17298   Mendocino County  39.550019 -123.438353
# 17299        Napa Valley  38.502469 -122.265389
# 17300             Oregon  43.804133 -120.554201
#
# [17301 rows x 6 columns]

# %%
des = data['description']

# %%
def token(sentence):
    tokens = word_tokenize(sentence)
    return tokens

# %%
data['tokens'] = des.apply(token)

# %%
data
# Out:
#        Unnamed: 0 country                                        description  \
# 0               4      US  Much like the regular bottling from 2012, this...
# 1              21      US  A sleek mix of tart berry, stem and herb, alon...
# 2              25      US  Oak and earth intermingle around robust aromas...
# 3              35      US  As with many of the Erath 2010 vineyard design...
# 4              41      US  A stiff, tannic wine, this slowly opens and br...
# ...           ...     ...                                                ...
# 17296      129936  France  A blend from several premier cru vineyards in ...
# 17297      129940      US  This is the winery's bells and whistles Chardo...
# 17298      129941      US  A Chardonnay with an unusual companion, 8% Sém...
# 17299      129949      US  There's no bones about the use of oak in this ...
# 17300      129967      US  Citation is given as much as a decade of bottl...
#
#                 region_1        lat         lon  \
# 0      Willamette Valley  44.942554 -122.933762
# 1                 Oregon  43.804133 -120.554201
# 2           Sonoma Coast  38.424211 -123.101173
# 3            McMinnville  45.210751 -123.194487
# 4      Willamette Valley  44.942554 -122.933762
# ...                  ...        ...         ...
# 17296            Pommard  47.009310    4.795325
# 17297          Mendocino  39.307674 -123.799459
# 17298   Mendocino County  39.550019 -123.438353
# 17299        Napa Valley  38.502469 -122.265389
# 17300             Oregon  43.804133 -120.554201
#
#                                                   tokens
# 0      [Much, like, the, regular, bottling, from, 201...
# 1      [A, sleek, mix, of, tart, berry, ,, stem, and,...
# 2      [Oak, and, earth, intermingle, around, robust,...
# 3      [As, with, many, of, the, Erath, 2010, vineyar...
# 4      [A, stiff, ,, tannic, wine, ,, this, slowly, o...
# ...                                                  ...
# 17296  [A, blend, from, several, premier, cru, vineya...
# 17297  [This, is, the, winery, 's, bells, and, whistl...
# 17298  [A, Chardonnay, with, an, unusual, companion, ...
# 17299  [There, 's, no, bones, about, the, use, of, oa...
# 17300  [Citation, is, given, as, much, as, a, decade,...
#
# [17301 rows x 7 columns]

# %%
count_vectorizer = CountVectorizer()
X = count_vectorizer.fit_transform(des)

# %%
vectorized_texts = pd.DataFrame(
    X.toarray(), 
    columns = count_vectorizer.get_feature_names_out(),
    index = data['description']
)

vectorized_texts
# Out:
#                                                     000  01  03  04  05  06  \
# description
# Much like the regular bottling from 2012, this ...    0   0   0   0   0   0
# A sleek mix of tart berry, stem and herb, along...    0   0   0   0   0   0
# Oak and earth intermingle around robust aromas ...    0   0   0   0   0   0
# As with many of the Erath 2010 vineyard designa...    0   0   0   0   0   0
# A stiff, tannic wine, this slowly opens and bri...    0   0   0   0   0   0
# ...                                                 ...  ..  ..  ..  ..  ..
# A blend from several premier cru vineyards in P...    0   0   0   0   0   0
# This is the winery's bells and whistles Chardon...    0   0   0   0   0   0
# A Chardonnay with an unusual companion, 8% Sémi...    0   0   0   0   0   0
# There's no bones about the use of oak in this w...    0   0   0   0   0   0
# Citation is given as much as a decade of bottle...    0   0   0   0   0   0
#
#                                                     06s  07  08  09  ...  \
# description                                                          ...
# Much like the regular bottling from 2012, this ...    0   0   0   0  ...
# A sleek mix of tart berry, stem and herb, along...    0   0   0   0  ...
# Oak and earth intermingle around robust aromas ...    0   0   0   0  ...
# As with many of the Erath 2010 vineyard designa...    0   0   0   0  ...
# A stiff, tannic wine, this slowly opens and bri...    0   0   0   0  ...
# ...                                                 ...  ..  ..  ..  ...
# A blend from several premier cru vineyards in P...    0   0   0   0  ...
# This is the winery's bells and whistles Chardon...    0   0   0   0  ...
# A Chardonnay with an unusual companion, 8% Sémi...    0   0   0   0  ...
# There's no bones about the use of oak in this w...    0   0   0   0  ...
# Citation is given as much as a decade of bottle...    0   0   0   0  ...
#
#                                                     zingy  zinny  zins  zip  \
# description
# Much like the regular bottling from 2012, this ...      0      0     0    0
# A sleek mix of tart berry, stem and herb, along...      0      0     0    0
# Oak and earth intermingle around robust aromas ...      0      0     0    0
# As with many of the Erath 2010 vineyard designa...      0      0     0    0
# A stiff, tannic wine, this slowly opens and bri...      0      0     0    0
# ...                                                   ...    ...   ...  ...
# A blend from several premier cru vineyards in P...      0      0     0    0
# This is the winery's bells and whistles Chardon...      0      0     0    0
# A Chardonnay with an unusual companion, 8% Sémi...      0      0     0    0
# There's no bones about the use of oak in this w...      0      0     0    0
# Citation is given as much as a decade of bottle...      0      0     0    0
#
#                                                     zippiness  zippy  zips  \
# description
# Much like the regular bottling from 2012, this ...          0      0     0
# A sleek mix of tart berry, stem and herb, along...          0      0     0
# Oak and earth intermingle around robust aromas ...          0      0     0
# As with many of the Erath 2010 vineyard designa...          0      0     0
# A stiff, tannic wine, this slowly opens and bri...          0      0     0
# ...                                                       ...    ...   ...
# A blend from several premier cru vineyards in P...          0      0     0
# This is the winery's bells and whistles Chardon...          0      0     0
# A Chardonnay with an unusual companion, 8% Sémi...          0      0     0
# There's no bones about the use of oak in this w...          0      0     0
# Citation is given as much as a decade of bottle...          0      0     0
#
#                                                     zone  zotovich  élévage
# description
# Much like the regular bottling from 2012, this ...     0         0        0
# A sleek mix of tart berry, stem and herb, along...     0         0        0
# Oak and earth intermingle around robust aromas ...     0         0        0
# As with many of the Erath 2010 vineyard designa...     0         0        0
# A stiff, tannic wine, this slowly opens and bri...     0         0        0
# ...                                                  ...       ...      ...
# A blend from several premier cru vineyards in P...     0         0        0
# This is the winery's bells and whistles Chardon...     0         0        0
# A Chardonnay with an unusual companion, 8% Sémi...     0         0        0
# There's no bones about the use of oak in this w...     0         0        0
# Citation is given as much as a decade of bottle...     0         0        0
#
# [17301 rows x 12567 columns]
